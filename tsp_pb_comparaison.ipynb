# %% [markdown]
# ### Comparaison of tsp algorism performance

# %%
# loading librarys
import numpy as np
import matplotlib.pyplot as plt
import time
import kmeans_tsp_solver
import asymmetric_tsp_solver
import evolutionary_tsp_solver

# %%
# load the data in lab2 directory
# n = [10, 20, 50, 100, 200, 500, 1000]
n = [10, 20, 50, 100, 200, 500, 1000]
restarts = [200, 100, 50, 30, 30, 10, 3]
g_pb = []
r1_pb = []
r2_pb = []

for i in n:
    data = np.load("lab2/problem_g_"+str(i)+".npy")
    g_pb.append(data)
    data = np.load("lab2/problem_r1_"+str(i)+".npy")
    r1_pb.append(data)
    data = np.load("lab2/problem_r2_"+str(i)+".npy")
    r2_pb.append(data)

print("Data loaded")
# Out:
# Data loaded

# %% [markdown]
# #### Using k-means symetric TSP solver on g problems

# %%
g_sol_sym = []
g_time_sym = []
g_cost_sym = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing g problem with n={n[i]} cities (symmetric solver)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = kmeans_tsp_solver.kmeans_tsp_solve(
        g_pb[i],
        max_clusters=max(n[i]//5, 10),
        restarts_per_cluster=30,
        general_restarts=restarts[i],
        auto_clusters=True,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    g_sol_sym.append(final_tour)
    g_time_sym.append(elapsed_time)
    g_cost_sym.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for g problems (symmetric solver):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={g_cost_sym[i]:10.2f}, time={g_time_sym[i]:6.2f}s")
# Out:
# ...
# Processing g problem with n=10 cities (symmetric solver)
# ...
# /home/adrien/.venvs/labo/lib/python3.12/site-packages/sklearn/manifold/_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(
# /home/adrien/.venvs/labo/lib/python3.12/site-packages/sklearn/manifold/_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(
# Completed in 1.22s, final cost: 1497.66
#
# ...
# Processing g problem with n=20 cities (symmetric solver)
# ...
# /home/adrien/.venvs/labo/lib/python3.12/site-packages/sklearn/manifold/_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(
# /home/adrien/.venvs/labo/lib/python3.12/site-packages/sklearn/manifold/_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(
# Completed in 1.36s, final cost: 1755.51
#
# ...
# Processing g problem with n=50 cities (symmetric solver)
# ...

# %% [markdown]
# #### Using asymmetric TSP solver on r1 problems

# %%
r1_sol_asym = []
r1_time_asym = []
r1_cost_asym = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing r1 problem with n={n[i]} cities (asymmetric solver)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = asymmetric_tsp_solver.asymmetric_tsp_solve(
        r1_pb[i],
        max_clusters=max(n[i]//5, 10),
        restarts_per_cluster=30,
        final_restarts=restarts[i],
        auto_clusters=True,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    r1_sol_asym.append(final_tour)
    r1_time_asym.append(elapsed_time)
    r1_cost_asym.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for r1 problems (asymmetric solver):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={r1_cost_asym[i]:10.2f}, time={r1_time_asym[i]:6.2f}s")
# Out:
# ...
# Processing r1 problem with n=10 cities (asymmetric solver)
# ...
#
# Completed in 1.52s, final cost: 184.27
#
# ...
# Processing r1 problem with n=20 cities (asymmetric solver)
# ...
#
# Completed in 1.52s, final cost: 184.27
#
# ...
# Processing r1 problem with n=20 cities (asymmetric solver)
# ...
#
# Completed in 1.33s, final cost: 343.90
#
# ...
# Processing r1 problem with n=50 cities (asymmetric solver)
# ...
#
# Completed in 1.33s, final cost: 343.90
#
# ...
# Processing r1 problem with n=50 cities (asymmetric solver)
# ...
#
# Completed in 2.11s, final cost: 571.10
#
# ...
# Processing r1 problem with n=100 cities (asymmetric solver)
# ...
#
# Completed in 2.11s, final cost: 571.10
#
# ...
# Processing r1 problem with n=100 cities (asymmetric solver)
# ...
#
# Completed in 6.19s, final cost: 870.19
#
# ...
# Processing r1 problem with n=200 cities (asymmetric solver)
# ...
#
# Completed in 6.19s, final cost: 870.19
#
# ...
# Processing r1 problem with n=200 cities (asymmetric solver)
# ...
#
# Completed in 11.24s, final cost: 1149.93
#
# ...

# %% [markdown]
# #### Using asymmetric TSP solver on r2 problems

# %%
r2_sol_asym = []
r2_time_asym = []
r2_cost_asym = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing r2 problem with n={n[i]} cities (asymmetric solver)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = asymmetric_tsp_solver.asymmetric_tsp_solve(
        r2_pb[i],
        max_clusters=max(n[i]//5, 10),
        restarts_per_cluster=30,
        final_restarts=restarts[i],
        auto_clusters=True,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    r2_sol_asym.append(final_tour)
    r2_time_asym.append(elapsed_time)
    r2_cost_asym.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for r2 problems (asymmetric solver):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={r2_cost_asym[i]:10.2f}, time={r2_time_asym[i]:6.2f}s")
# Out:
# ...
# Processing r2 problem with n=10 cities (asymmetric solver)
# ...
#
# Completed in 3.87s, final cost: -411.70
#
# ...
# Processing r2 problem with n=20 cities (asymmetric solver)
# ...
#
# Completed in 3.87s, final cost: -411.70
#
# ...
# Processing r2 problem with n=20 cities (asymmetric solver)
# ...
#
# Completed in 2.26s, final cost: -785.44
#
# ...
# Processing r2 problem with n=50 cities (asymmetric solver)
# ...
#
# Completed in 2.26s, final cost: -785.44
#
# ...
# Processing r2 problem with n=50 cities (asymmetric solver)
# ...
#
# Completed in 3.86s, final cost: -1966.82
#
# ...
# Processing r2 problem with n=100 cities (asymmetric solver)
# ...
#
# Completed in 3.86s, final cost: -1966.82
#
# ...
# Processing r2 problem with n=100 cities (asymmetric solver)
# ...
#
# Completed in 5.49s, final cost: -4183.79
#
# ...
# Processing r2 problem with n=200 cities (asymmetric solver)
# ...
#
# Completed in 5.49s, final cost: -4183.79
#
# ...
# Processing r2 problem with n=200 cities (asymmetric solver)
# ...
#
# Completed in 28.05s, final cost: -8433.16
#
# ...

# %% [markdown]
# #### Using asymmetric TSP solver on g problems

# %%
g_sol_asym = []
g_time_asym = []
g_cost_asym = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing g problem with n={n[i]} cities (asymmetric solver)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = asymmetric_tsp_solver.asymmetric_tsp_solve(
        g_pb[i],
        max_clusters=max(n[i]//5, 10),
        restarts_per_cluster=30,
        final_restarts=restarts[i],
        auto_clusters=True,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    g_sol_asym.append(final_tour)
    g_time_asym.append(elapsed_time)
    g_cost_asym.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for g problems (asymmetric solver):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={g_cost_asym[i]:10.2f}, time={g_time_asym[i]:6.2f}s")
# Out:
# ...
# Processing g problem with n=10 cities (asymmetric solver)
# ...
#
# Completed in 0.28s, final cost: 1497.66
#
# ...
# Processing g problem with n=20 cities (asymmetric solver)
# ...
#
# Completed in 0.40s, final cost: 1755.51
#
# ...
# Processing g problem with n=50 cities (asymmetric solver)
# ...
#
# Completed in 0.99s, final cost: 2712.04
#
# ...
# Processing g problem with n=100 cities (asymmetric solver)
# ...
#
# Completed in 1.74s, final cost: 4005.38
#
# ...
# Processing g problem with n=200 cities (asymmetric solver)
# ...
#
# Completed in 5.45s, final cost: 5629.14
#
# ...
# Processing g problem with n=500 cities (asymmetric solver)
# ...
#
# Completed in 11.61s, final cost: 8740.19
#
# ...
# Processing g problem with n=1000 cities (asymmetric solver)
# ...
#
# Completed in 15.76s, final cost: 12567.83
#
# ...
# Summary for g problems (asymmetric solver):
# ...
# n=  10: cost=   1497.66, time=  0.28s
# n=  20: cost=   1755.51, time=  0.40s
# n=  50: cost=   2712.04, time=  0.99s
# n= 100: cost=   4005.38, time=  1.74s
# n= 200: cost=   5629.14, time=  5.45s
# ...

# %%
r2_sol_evo = []
r2_time_evo = []
r2_cost_evo = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing r2 problem with n={n[i]} cities (evolutionary)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = evolutionary_tsp_solver.evolutionary_tsp_solve(
        r2_pb[i],
        population_size=None,  # Auto-adjust
        generations=None,      # Auto-adjust
        elite_size=10,
        mutation_rate=0.15,
        local_search=True,
        local_search_freq=20,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    r2_sol_evo.append(final_tour)
    r2_time_evo.append(elapsed_time)
    r2_cost_evo.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for r2 problems (evolutionary):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={r2_cost_evo[i]:10.2f}, time={r2_time_evo[i]:6.2f}s")

# %% [markdown]
# #### Using evolutionary algorithm on r2 problems

# %%
r1_sol_evo = []
r1_time_evo = []
r1_cost_evo = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing r1 problem with n={n[i]} cities (evolutionary)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = evolutionary_tsp_solver.evolutionary_tsp_solve(
        r1_pb[i],
        population_size=None,  # Auto-adjust
        generations=None,      # Auto-adjust
        elite_size=10,
        mutation_rate=0.15,
        local_search=True,
        local_search_freq=20,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    r1_sol_evo.append(final_tour)
    r1_time_evo.append(elapsed_time)
    r1_cost_evo.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for r1 problems (evolutionary):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={r1_cost_evo[i]:10.2f}, time={r1_time_evo[i]:6.2f}s")

# %% [markdown]
# #### Using evolutionary algorithm on r1 problems

# %%
g_sol_evo = []
g_time_evo = []
g_cost_evo = []

for i in range(len(n)):
    print(f"\n{'='*60}")
    print(f"Processing g problem with n={n[i]} cities (evolutionary)")
    print(f"{'='*60}")
    
    start_time = time.time()
    
    final_tour, cost_breakdown = evolutionary_tsp_solver.evolutionary_tsp_solve(
        g_pb[i],
        population_size=None,  # Auto-adjust
        generations=None,      # Auto-adjust
        elite_size=10,
        mutation_rate=0.15,
        local_search=True,
        local_search_freq=20,
        verbose=False
    )
    
    elapsed_time = time.time() - start_time
    
    g_sol_evo.append(final_tour)
    g_time_evo.append(elapsed_time)
    g_cost_evo.append(cost_breakdown['final'])
    
    print(f"\nCompleted in {elapsed_time:.2f}s, final cost: {cost_breakdown['final']:.2f}")

print("\n" + "="*60)
print("Summary for g problems (evolutionary):")
print("="*60)
for i in range(len(n)):
    print(f"n={n[i]:4d}: cost={g_cost_evo[i]:10.2f}, time={g_time_evo[i]:6.2f}s")

# %% [markdown]
# #### Using evolutionary algorithm on g problems

# %% [markdown]
# #### Visualization of Results

# %%
# Plot execution times
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Time comparison
ax1.plot(n, g_time_sym, 'o-', label='g (k-means/symmetric)', linewidth=2, markersize=8, color='blue')
ax1.plot(n, g_time_asym, 'o--', label='g (asymmetric solver)', linewidth=2, markersize=8, color='cyan')
ax1.plot(n, r1_time_asym, 's-', label='r1 (asymmetric)', linewidth=2, markersize=8, color='orange')
ax1.plot(n, r2_time_asym, '^-', label='r2 (asymmetric)', linewidth=2, markersize=8, color='red')
ax1.set_xlabel('Number of cities (n)', fontsize=12)
ax1.set_ylabel('Execution time (seconds)', fontsize=12)
ax1.set_title('Execution Time Comparison', fontsize=14, fontweight='bold')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_xscale('log')
ax1.set_yscale('log')

# Cost comparison
ax2.plot(n, g_cost_sym, 'o-', label='g (k-means/symmetric)', linewidth=2, markersize=8, color='blue')
ax2.plot(n, g_cost_asym, 'o--', label='g (asymmetric solver)', linewidth=2, markersize=8, color='cyan')
ax2.plot(n, r1_cost_asym, 's-', label='r1 (asymmetric)', linewidth=2, markersize=8, color='orange')
ax2.plot(n, r2_cost_asym, '^-', label='r2 (asymmetric)', linewidth=2, markersize=8, color='red')
ax2.set_xlabel('Number of cities (n)', fontsize=12)
ax2.set_ylabel('Tour cost', fontsize=12)
ax2.set_title('Solution Cost Comparison', fontsize=14, fontweight='bold')
ax2.legend()
ax2.grid(True, alpha=0.3)
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.tight_layout()
plt.show()

# Print detailed comparison table
print("\n" + "="*100)
print("DETAILED COMPARISON TABLE")
print("="*100)
print(f"{'n':>6} | {'g (k-means)':>25} | {'g (asym solver)':>25} | {'r1 (asym)':>25} | {'r2 (asym)':>25}")
print(f"{'':>6} | {'Cost':>12} {'Time':>12} | {'Cost':>12} {'Time':>12} | {'Cost':>12} {'Time':>12} | {'Cost':>12} {'Time':>12}")
print("-"*100)
for i in range(len(n)):
    print(f"{n[i]:6d} | {g_cost_sym[i]:12.2f} {g_time_sym[i]:11.2f}s | "
          f"{g_cost_asym[i]:12.2f} {g_time_asym[i]:11.2f}s | "
          f"{r1_cost_asym[i]:12.2f} {r1_time_asym[i]:11.2f}s | "
          f"{r2_cost_asym[i]:12.2f} {r2_time_asym[i]:11.2f}s")
print("="*100)
# Out:
# ...
# DETAILED COMPARISON TABLE
# ...
#      n |               g (k-means) |           g (asym solver) |                 r1 (asym) |                 r2 (asym)
#        |         Cost         Time |         Cost         Time |         Cost         Time |         Cost         Time
# ----------------------------------------------------------------------------------------------------
#     10 |      1497.66        0.45s |      1497.66        0.28s |       188.21        0.33s |      -411.70        0.35s
#     20 |      1755.51        0.66s |      1755.51        0.40s |       341.62        0.53s |      -784.85        0.63s
#     50 |      2643.65        1.27s |      2712.04        0.99s |       549.24        1.16s |     -2009.70        2.06s
#    100 |      4023.12        2.33s |      4005.38        1.74s |       778.78        2.96s |     -4156.96        5.01s
#    200 |      5675.06        7.86s |      5629.14        5.45s |      1139.01       15.83s |     -8691.84       27.72s
# ...

# %% [markdown]
# ====================================================================================================
# DETAILED COMPARISON TABLE
# ====================================================================================================
#      n |               g (k-means) |           g (asym solver) |                 r1 (asym) |                 r2 (asym)
#        |         Cost         Time |         Cost         Time |         Cost         Time |         Cost         Time
# ----------------------------------------------------------------------------------------------------
#     10 |      1497.66        0.31s |      1497.66        0.17s |       188.21        0.20s |      -390.60        0.24s
#     20 |      1755.51        0.47s |      1755.51        0.22s |       345.70        0.25s |      -739.40        0.31s
#     50 |      2827.41        0.65s |      2805.59        0.52s |       553.77        0.59s |     -2055.89        0.91s
#    100 |      4149.29        1.04s |      4096.68        0.84s |       828.42        1.63s |     -4112.54        1.98s
#    200 |      5785.94        2.83s |      5794.66        2.24s |      1126.75        5.93s |     -8490.15        9.56s
#    500 |      9003.46       21.18s |      8950.01        4.42s |      1768.56        7.16s |    -22673.50       11.35s
#   1000 |     12574.76       70.15s |     12662.56       19.73s |      2511.16       28.19s |    -45935.86       42.77s
# ====================================================================================================
#
# a lot of restarts
# ====================================================================================================
# DETAILED COMPARISON TABLE
# ====================================================================================================
#      n |               g (k-means) |           g (asym solver) |                 r1 (asym) |                 r2 (asym)
#        |         Cost         Time |         Cost         Time |         Cost         Time |         Cost         Time
# ----------------------------------------------------------------------------------------------------
#     10 |      1497.66        0.43s |      1497.66        1.53s |       196.69        0.49s |      -387.05        0.35s
#     20 |      1755.51        0.81s |      1755.51        0.59s |       351.03        0.46s |      -726.99        0.58s
#     50 |      2678.41        1.31s |      2708.93        1.08s |       576.13        1.13s |     -1973.50        1.38s
#    100 |      4209.56        2.01s |      4173.60        2.45s |       877.73        3.58s |     -4137.52        3.48s
#    200 |      5737.98        5.75s |      5833.38        6.47s |      1154.83       10.86s |     -8608.37       15.19s
#    500 |      8996.79       39.82s |      8821.58       25.67s |      1782.39       41.51s |    -22597.31       79.60s
#   1000 |     12551.18      131.07s |     12438.63       92.57s |      2531.17      150.22s |    -46032.36      295.10s
# ====================================================================================================
#
# less (balanced) restarts
# ====================================================================================================
# DETAILED COMPARISON TABLE
# ====================================================================================================
#      n |               g (k-means) |           g (asym solver) |                 r1 (asym) |                 r2 (asym)
#        |         Cost         Time |         Cost         Time |         Cost         Time |         Cost         Time
# ----------------------------------------------------------------------------------------------------
#     10 |      1497.66        0.45s |      1497.66        0.28s |       188.21        0.33s |      -411.70        0.35s
#     20 |      1755.51        0.66s |      1755.51        0.40s |       341.62        0.53s |      -784.85        0.63s
#     50 |      2643.65        1.27s |      2712.04        0.99s |       549.24        1.16s |     -2009.70        2.06s
#    100 |      4023.12        2.33s |      4005.38        1.74s |       778.78        2.96s |     -4156.96        5.01s
#    200 |      5675.06        7.86s |      5629.14        5.45s |      1139.01       15.83s |     -8691.84       27.72s
#    500 |      8849.96       28.66s |      8740.19       11.61s |      1744.49       15.58s |    -22715.02       35.21s
#   1000 |     12698.62       59.11s |     12567.83       15.76s |      2547.82       33.46s |    -45856.87       40.54s
# ====================================================================================================
#
# solution exacte for r1 and r2 not found in time limit for n >= 20
# 10- g :1497.663648225291 r1: 184.27344079993895 r2: -411.7017155524984
# 20- g :1755.5146770830047 r1: 337.29487214725555 r2: -861.6672062881738
